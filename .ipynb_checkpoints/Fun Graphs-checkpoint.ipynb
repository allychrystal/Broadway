# %% [markdown]
# ## Bullish on Broadway:  Can the model predict a hit or flop?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from datetime import datetime

# %%
index = pd.read_csv('index.csv')

# %%
index = index.set_index('ID')

# %%
df = pd.read_csv('ibdb_1.csv')

# %%
def fill_nulls(data):
    data['GrossChange'] = data['GrossChange'].fillna(0)
    data['AttChange'] = data['AttChange'].fillna(0)
    data['TopTicket'] = data['TopTicket'].fillna(data['AvgTicket'])
    return data

df = fill_nulls(df)

# %%
df = df.dropna()

# %%
df.head()
# Out:
#    ID              Show         Theatre     Gross  Potential  Rev%  \
# 0   1  [title of show]   Lyceum Theatre   69299.0   198534.0  0.35
# 1   1  [title of show]   Lyceum Theatre  163916.0   520826.0  0.31
# 2   1  [title of show]   Lyceum Theatre  154121.0   520826.0  0.30
# 3   1  [title of show]   Lyceum Theatre  162682.0   520826.0  0.31
# 4   1  [title of show]   Lyceum Theatre  178183.0   520826.0  0.34
#
#    GrossChange  Attendance  Capacity  Att%  AttChange  AvgTicket  TopTicket  \
# 0          0.0      1490.0    2766.0  0.54        0.0       46.5      200.0
# 1      94617.0      3863.0    7312.0  0.53     2373.0       42.4      200.0
# 2      -9795.0      3543.0    7312.0  0.48     -320.0       43.5      200.0
# 3       8561.0      3786.0    7312.0  0.52      243.0       43.0      200.0
# 4      15501.0      3986.0    7312.0  0.55      200.0       44.7      200.0
#
#    Performances  Previews     Week  Month  Year
# 0             0         3   7/6/08      7  2008
# 1             0         8  7/13/08      7  2008
# 2             6         2  7/20/08      7  2008
# 3             8         0  7/27/08      7  2008
# 4             8         0   8/3/08      8  2008

# %%
df['Week'] = pd.to_datetime(df.Week)

# %%
def graph_attendance(show):
    x = df.loc[df.ID == show, :]
    x = x.set_index('Week')
    fig, ax = plt.subplots(figsize=[15,5])
    fig.autofmt_xdate()
    plt.plot(x.index, x.Attendance, color='green', label='Attendance')
    plt.plot(x.index, x.Capacity, color='red', label='Capacity')
    plt.title(index.Show[show], size =20)
    plt.xlabel('Date')
    plt.ylabel('Attendance/ Capacity')
    plt.legend()

graph_attendance(88)

# %%
def graph_gross(show):
    x = df.loc[df.ID == show, :]
    x = x.set_index('Week')
    fig, ax = plt.subplots(figsize=[15,5])
    fig.autofmt_xdate()
    plt.plot(x.index, x.Gross, color='green', label='Gross')
    plt.plot(x.index, x.Potential, color='red', label='Potential')
    plt.title(index.Show[show], size=20)
    plt.xlabel('Date')
    plt.ylabel('Gross/ Potential')
    plt.legend()

graph_gross(222)
